# %%
import os 
import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/marcinurbanski/Desktop/jmu_repo/projekt_300_fertility_pred'

# %%
data = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/project_200_conflicts/20260322.export.CSV',delimiter='/t',quotechar='""')
# Out:
# /var/folders/1_/28vylhx11cs54zyvgx55gyfw0000gn/T/ipykernel_8033/3749228969.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/project_200_conflicts/20260322.export.CSV',delimiter='/t',quotechar='""')
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 data = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/project_200_conflicts/20260322.export.CSV',delimiter='/t',quotechar='""')
#
# ...

# %%
data
# Out:
#       1295476897\t20250322\t202503\t2025\t2025.2247\tGOV\tGOVERNMENT\t\t\t\t\t\tGOV\t\t\tMUS\tMAURITIUS\tMUS\t\t\t\t\t\t\t\t0\t050\t050\t05\t1\t3.5\t60\t10\t60\t-3.20718201555948\t4\tChagos Archipelago, Mauritius (general), Mauritius\tMP\tMP00\t-6\t72\t-1355685\t4\tChagos Archipelago, Mauritius (general), Mauritius\tMP\tMP00\t-6\t72\t-1355685\t4\tChagos Archipelago, Mauritius (general), Mauritius\tMP\tMP00\t-6\t72\t-1355685\t20260322\thttps://www.cecildaily.com/ap/world/what-to-know-about-diego-garcia-after-iran-targets-the-remote-islands-key-us-military/article_c103b5d0-622b-55ec-b6d3-d446a1ae449a.html
# 0      1295476898\t20250322\t202503\t2025\t2025.2247\...
# 1      1295476899\t20250322\t202503\t2025\t2025.2247\...
# 2      1295476900\t20250322\t202503\t2025\t2025.2247\...
# 3      1295476901\t20250322\t202503\t2025\t2025.2247\...
# 4      1295476902\t20250322\t202503\t2025\t2025.2247\...
# ...                                                  ...
# ...
