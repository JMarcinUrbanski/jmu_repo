# %%
import os
import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/marcinurbanski/Desktop/jmu_repo'

# %%
df = pd.read_csv('/Users/marcinurbanski/Desktop/MERITO_KURS_PLIKI/05_UCZENIE_MASZYNOWE/houses.csv')

# %%
df.head()
# Out:
#    Jakosc  Powierzchnia  PowierzchniaPiwnicy  LiczbaMscGaraz  \
# 0       7          1710                  856               2
# 1       6          1262                 1262               2
# 2       7          1786                  920               2
# 3       7          1717                  756               3
# 4       8          2198                 1145               3
#
#    PowierzchniaGarazu  RokBudowy  LiczbaLazienek  Powierzchnia1Pietra  \
# 0                 548       2003               2                  856
# 1                 460       1976               2                 1262
# 2                 608       2001               2                  920
# 3                 642       1915               1                  961
# 4                 836       2000               2                 1145
#
#    LiczbaPokoi TypGarazu  DlugoscDzialkiPrzyUlicy Sasiedztwo    Cena  jmu
# 0            8    Attchd                     65.0    CollgCr  208500  jmu
# ...

# %%
pd.DataFrame(df['TypGarazu'].unique())[0]
# Out:
# 0     Attchd
# 1     Detchd
# 2    BuiltIn
# 3    CarPort
# 4        NaN
# 5    Basment
# 6     2Types
# Name: 0, dtype: object

# %%
map = {
    'Attchd': 1,
    'Detchd': 2,
    'BuiltIn': 3,
    'CarPort': 4,
    'Basment': 5,
    '2Types': 6,
    'nan': 0,
}


df['jmu3'] = df['TypGarazu'].map(map)

# %%
df.head()
# Out:
#    Jakosc  Powierzchnia  PowierzchniaPiwnicy  LiczbaMscGaraz  \
# 0       7          1710                  856               2
# 1       6          1262                 1262               2
# 2       7          1786                  920               2
# 3       7          1717                  756               3
# 4       8          2198                 1145               3
#
#    PowierzchniaGarazu  RokBudowy  LiczbaLazienek  Powierzchnia1Pietra  \
# 0                 548       2003               2                  856
# 1                 460       1976               2                 1262
# 2                 608       2001               2                  920
# 3                 642       1915               1                  961
# 4                 836       2000               2                 1145
#
#    LiczbaPokoi TypGarazu  DlugoscDzialkiPrzyUlicy Sasiedztwo    Cena  jmu  \
# 0            8    Attchd                     65.0    CollgCr  208500    1
# ...

# %%
df[['TypGarazu','jmu2','jmu','jmu3']].loc[df['jmu']==0]
# Out:
#      TypGarazu  jmu2  jmu  jmu3
# 39         nan     0    0     0
# 48         nan     0    0     0
# 78         nan     0    0     0
# 88         nan     0    0     0
# 89         nan     0    0     0
# ...        ...   ...  ...   ...
# 1407       nan     0    0     0
# 1449       nan     0    0     0
# 1450       nan     0    0     0
# 1452   Basment     5    0     5
# 1453       nan     0    0     0
#
# [106 rows x 4 columns]

# %%
df['jmu2']=df['jmu2'].astype('int64')

# %%
type(df['jmu2'][0])
# Out:
# numpy.int64

# %%
df.loc[df['TypGarazu']== 'NaN' ]
# Out:
# Empty DataFrame
# Columns: [Jakosc, Powierzchnia, PowierzchniaPiwnicy, LiczbaMscGaraz, PowierzchniaGarazu, RokBudowy, LiczbaLazienek, Powierzchnia1Pietra, LiczbaPokoi, TypGarazu, DlugoscDzialkiPrzyUlicy, Sasiedztwo, Cena, jmu, jmu2]
# Index: []

# %%
ls_nan = [e for e in df['TypGarazu'] if e not in ['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'Basment', '2Types']]

# %%
#type(ls_nan[0])
ls_nan[2]
# Out:
# nan

# %%
df['TypGarazu'] = df['TypGarazu'].astype(str)

# %%
df['TypGarazu'].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'nan', 'Basment',
#        '2Types'], dtype=object)

# %%
jmu = []

for e in df['TypGarazu']:
    if e == 'Attchd':
        jmu.append(1)
    elif e == 'Detchd':
         jmu.append(2)
    elif e == 'BuiltIn':
        jmu.append(3)
    elif e == 'CarPort':
        jmu.append(4)
    else:
        jmu.append(0)
df['jmu'] = jmu

df.head()
# Out:
#    Jakosc  Powierzchnia  PowierzchniaPiwnicy  LiczbaMscGaraz  \
# 0       7          1710                  856               2
# 1       6          1262                 1262               2
# 2       7          1786                  920               2
# 3       7          1717                  756               3
# 4       8          2198                 1145               3
#
#    PowierzchniaGarazu  RokBudowy  LiczbaLazienek  Powierzchnia1Pietra  \
# 0                 548       2003               2                  856
# 1                 460       1976               2                 1262
# 2                 608       2001               2                  920
# 3                 642       1915               1                  961
# 4                 836       2000               2                 1145
#
#    LiczbaPokoi TypGarazu  DlugoscDzialkiPrzyUlicy Sasiedztwo    Cena  jmu
# 0            8    Attchd                     65.0    CollgCr  208500    1
# ...

# %%
df.drop(labels=['jmu'],axis=1)
# Out:
#       Jakosc  Powierzchnia  PowierzchniaPiwnicy  LiczbaMscGaraz  \
# 0          7          1710                  856               2
# 1          6          1262                 1262               2
# 2          7          1786                  920               2
# 3          7          1717                  756               3
# 4          8          2198                 1145               3
# ...      ...           ...                  ...             ...
# 1455       6          1647                  953               2
# 1456       6          2073                 1542               2
# 1457       7          2340                 1152               1
# 1458       5          1078                 1078               1
# 1459       5          1256                 1256               1
#
#       PowierzchniaGarazu  RokBudowy  LiczbaLazienek  Powierzchnia1Pietra  \
# 0                    548       2003               2                  856
# ...
