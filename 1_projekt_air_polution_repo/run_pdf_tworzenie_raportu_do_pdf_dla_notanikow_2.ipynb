# %%
# !pip install nbconvert

# %%
# !pip install nbconvert\[webpdf\]

# %%
# !jupyter nbconvert "1_PROJEKT_MAIN_PZ.ipynb" --to webpdf --allow-chromium-download --TemplateExporter.exclude_input=True
# Out:
# [NbConvertApp] Converting notebook 1_PROJEKT_MAIN_PZ.ipynb to webpdf
# [NbConvertApp] WARNING | Alternative text is missing on 18 image(s).
# [NbConvertApp] Building PDF
# ...

# %%
# %pip instal --upgrade jinja2
# Out:
# ERROR: unknown command "instal" - maybe you meant "install"
# Note: you may need to restart the kernel to use updated packages.
