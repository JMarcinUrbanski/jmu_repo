# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn 
#EDA
from pathlib import Path
from ydata_profiling import ProfileReport
from IPython.display import IFrame

# %% [markdown]
# ### LOAD DATASET

# %%
data_path = os.getcwd()
data_path
# Out:
# '/Users/marcinurbanski/Desktop/jmu_repo'

# %% [markdown]
# ## Dataset&Columns explanation

# %%
exp_col = pd.read_csv('conflict_dataset_columns.csv',usecols=[0,1],index_col=[0])
exp_col
# Out:
#                                                             Description
# Column Name
# conflict_id           Unique identifier assigned to each conflict in...
# location                         Country where the conflict takes place
# side_a                Primary actor on side A (usually the governmen...
# side_a_id               Numeric identifier for the main actor on side A
# side_a_2nd                Secondary actor or supporting group on side A
# side_b                              Primary opposing actor (rebel group
# side_b_id               Numeric identifier for the main actor on side B
# side_b_2nd                Secondary actor or supporting group on side B
# incompatibility       Main issue of the conflict such as government ...
# territory_name        Name of the territory if the conflict concerns...
# year                  Year of the observation in which the conflict ...
# intensity_level         Level of conflict intensity (1 = minor conflict
# ...

# %%
data['type_of_conflict'].unique()
# Out:
# array([3, 2, 4, 1])

# %%
data = pd.read_csv('conflict_data.csv')
display(data.head())
print('-'*140)
print(data.shape)
print('-'*140)
print(data.info())
# Out:
#    conflict_id       location               side_a side_a_id side_a_2nd  \
# 0        11342          India  Government of India       141        NaN
# 1        11342          India  Government of India       141        NaN
# 2        11343  Egypt, Israel  Government of Egypt       117        NaN
# 3        11343  Egypt, Israel  Government of Egypt       117        NaN
# 4        11343  Egypt, Israel  Government of Egypt       117        NaN
#
#                  side_b side_b_id side_b_2nd  incompatibility territory_name  \
# 0                  GNLA      1163        NaN                1       Garoland
# 1                  GNLA      1163        NaN                1       Garoland
# 2  Government of Israel       121        NaN                1     Suez/Sinai
# 3  Government of Israel       121        NaN                1     Suez/Sinai
# 4  Government of Israel       121        NaN                1     Suez/Sinai
#
# ...

# %%
target = [
X = [c for c in data.columns if c is not target]
y = target

# %%
num_cols = data.select_dtypes(include = ['int64','float64']).columns.tolist()
cat_cols = data.select_dtypes(include = ['object']).columns.tolist()

# %%
data[data['type_of_conflict']==1]
# Out:
#       conflict_id              location                        side_a  \
# 199           201  Cambodia (Kampuchea)          Government of France
# 200           201  Cambodia (Kampuchea)          Government of France
# 201           201  Cambodia (Kampuchea)          Government of France
# 202           201  Cambodia (Kampuchea)          Government of France
# 203           201  Cambodia (Kampuchea)          Government of France
# ...           ...                   ...                           ...
# 1171          285            Mozambique        Government of Portugal
# 1172          286           South Yemen  Government of United Kingdom
# 1173          286           South Yemen  Government of United Kingdom
# 1174          286           South Yemen  Government of United Kingdom
# 1175          286           South Yemen  Government of United Kingdom
#
#      side_a_id side_a_2nd         side_b side_b_id side_b_2nd  \
# 199         33        NaN  Khmer Issarak       160        NaN
# ...

# %%
X =
# Out:
# ['location',
#  'side_a',
#  'side_a_id',
#  'side_a_2nd',
#  'side_b',
#  'side_b_id',
#  'side_b_2nd',
#  'territory_name',
#  'start_date',
#  'start_date2',
#  'ep_end_date',
#  'gwno_a',
#  'gwno_a_2nd',
#  'gwno_b',
#  'gwno_b_2nd',
#  'gwno_loc',
#  'region']
