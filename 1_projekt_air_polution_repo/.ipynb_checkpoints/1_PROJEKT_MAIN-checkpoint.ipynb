# %% [markdown]
# # PROJEKT : <span style="margin-left:40px;"> Jerzy Marcin Urbański</span>
#
# ##### TEMAT:
# ## Analiza Jakości Powietrza Dla Wybranych Lokalizacji Oraz Okresów

# %% [markdown]
# Importy Bibliotek wraz z ich opisem

# %% [markdown]
# Sekcja bibliotek EDA

# %%
# ### pandas

# Biblioteka do pracy z danymi tabelarycznymi (DataFrame), umożliwia łatwe filtrowanie, grupowanie i przekształcanie danych. 
# Używana głównie do analizy danych, czyszczenia danych oraz wczytywania/zapisywania plików (CSV, Excel, SQL).
import pandas as pd

# ### numpy
# Podstawowa biblioteka do obliczeń numerycznych w Pythonie, oferująca wydajne operacje na tablicach wielowymiarowych. 
# Wykorzystywana do obliczeń matematycznych, statystycznych oraz jako fundament dla innych bibliotek analitycznych.
import numpy as np

# ### os
# Biblioteka standardowa do interakcji z systemem operacyjnym, umożliwia pracę z plikami i katalogami oraz zmiennymi środowiskowymi. 
#Używana m.in. do automatyzacji operacji na plikach i zarządzania ścieżkami.
import os

# ### matplotlib
# Biblioteka do tworzenia wykresów i wizualizacji danych w Pythonie. Pozwala generować różne typy wykresów (liniowe, słupkowe, histogramy) 
# oraz dostosowywać ich wygląd.
import matplotlib.pyplot as plt

# ### seaborn
# Rozszerzenie matplotlib, które upraszcza tworzenie estetycznych i statystycznych wizualizacji danych. 
# Umożliwia szybkie generowanie wykresów takich jak heatmapy, wykresy rozkładu czy zależności między zmiennymi.
import seaborn as sns

# ### ydata_profiling
# Biblioteka do automatycznej analizy eksploracyjnej danych (EDA), generująca szczegółowe raporty o zbiorze danych. 
# Pokazuje statystyki, brakujące wartości, korelacje i potencjalne problemy w danych.
from ydata_profiling import ProfileReport

# ### IPython.display
# Moduł umożliwiający wyświetlanie różnych typów treści w notebookach (HTML, obrazy, wideo). 
#  Używany do wzbogacania prezentacji wyników analiz i tworzenia interaktywnych raportów.
from IPython.display import IFrame
from pathlib import Path

# %% [markdown]
# Sekcja bibliotek ML

# %%
# import....

# %% [markdown]
# ## STEP 1.
# Import danych z plików csv , ostateczne sprawdznie oraz potrzebna agregacja do ostatecznej wersji.

# %% [markdown]
# ### 1.1. - Tabele Pogodowe - ready_weather[...]

# %% [markdown]
# ##### 1.1.1. Import wszyskich plików do odpowiednich zmiennych

# %%
# import wszyskich plików do odpowiednich zmiennych 

w_ld_2004 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/ready_weather_ld_2004.csv')
w_ld_2024 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/ready_weather_ld_2024.csv')
w_pz_2004 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/ready_weather_pz_2004.csv')
w_pz_2024 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/ready_weather_pz_2024.csv')

# %%
# szybkie sprawdznie 

display(w_ld_2004.head(2))
# display(w_ld_2024.head(2))
# display(w_pz_2004.head(2))
# display(w_pz_2024.head(2))
# Out:
#    Unnamed: 0                 time  latitude  longitude  number    step  \
# 0           0  2004-01-01 00:00:00     51.75       19.5       0  0 days
# 1           1  2004-01-01 06:00:00     51.75       19.5       0  0 days
#
#    surface           valid_time       u10       v10        t2m        blh  \
# 0      0.0  2004-01-01 00:00:00  0.794144 -3.466965  272.89502  413.98730
# 1      0.0  2004-01-01 06:00:00  0.833252 -3.170166  271.41577  404.84766
#
#          sp       tcc
# 0  99670.00  0.989990
# 1  99482.06  0.983978

# %% [markdown]
# #### 1.1.2 - Agregacja danych do postaci uniwersalnego DataFrame

# %%
# usunięcie niepotrzebnych kolumn ['Unnamed: 0','latitude','longitude','step','surface','valid_time']

# %%
# Selekscja kolumn do usunięcia 

# print(w_ld_2004['step'].nunique()) # kolumna ma jeden wynik -> usunać
# print('-'*140)
# print(w_ld_2004['surface'].nunique()) # kolumna ma jeden wynik -> usunać
# print('-'*140)
# print(w_ld_2004[w_ld_2004["time"] != w_ld_2004["valid_time"]]) # kolumna 'valid_time' powtrza wartosci 'time' -> usunać 
# print('-'*140)
# print(w_ld_2004['number'].nunique())

# %%
# Usunięcie kolumn bez wartości dla dalszej analizy.

w_ld_2004 = w_ld_2004.drop(['Unnamed: 0','latitude','longitude','step','surface','valid_time','number'], axis=1)
w_ld_2024 = w_ld_2024.drop(['Unnamed: 0','latitude','longitude','step','surface','valid_time','number'], axis=1)
w_pz_2004 = w_pz_2004.drop(['Unnamed: 0','latitude','longitude','step','surface','valid_time','number'], axis=1)
w_pz_2024 = w_pz_2024.drop(['Unnamed: 0','latitude','longitude','step','surface','valid_time','number'], axis=1)

# %%
w_ld_2004['time'] = pd.to_datetime(w_ld_2004['time'])
w_ld_2024['time'] = pd.to_datetime(w_ld_2024['time'])
w_pz_2004['time'] = pd.to_datetime(w_pz_2004['time'])
w_pz_2024['time'] = pd.to_datetime(w_pz_2024['time'])

# %%
w_ld_2004['city'] = 'LD'
w_ld_2024['city'] = 'LD'
w_pz_2004['city'] = 'PZ'
w_pz_2024['city'] = 'PZ'
w_pz_2024.head()
# Out:
#                  time       u10       v10        t2m        blh        sp  \
# 0 2024-01-01 00:00:00  0.916779  2.373703  276.52270  171.43484  99595.56
# 1 2024-01-01 06:00:00  2.034958  1.306549  276.30347  164.58713  99511.75
# 2 2024-01-01 12:00:00  3.338638  1.055939  278.74780  529.93410  99504.81
# 3 2024-01-01 18:00:00  3.177460  0.872955  277.53662  409.93090  99615.31
# 4 2024-01-02 00:00:00  3.800644  1.477478  277.71387  467.85132  99671.06
#
#         tcc city
# 0  1.000000   PZ
# 1  1.000000   PZ
# 2  1.000000   PZ
# 3  0.695404   PZ
# 4  0.946899   PZ

# %%
# Rozbicie daty/godziny 'time' na szczegóły i zapisanie w nowych kolumnach 
    #zamiana wartości w kolumnie 'time' na typ datetime
w_ld_2004['time'] = pd.to_datetime(w_ld_2004['time'])
w_ld_2024['time'] = pd.to_datetime(w_ld_2024['time'])
w_pz_2004['time'] = pd.to_datetime(w_pz_2004['time'])
w_pz_2024['time'] = pd.to_datetime(w_pz_2024['time'])

w_ld_2004 = w_ld_2004.assign(
    month=w_ld_2004['time'].dt.month_name(),
    year=w_ld_2004['time'].dt.year,
    day=w_ld_2004['time'].dt.day,
    day_of_week=w_ld_2004['time'].dt.day_name())

w_ld_2024 = w_ld_2024.assign(
    month=w_ld_2024['time'].dt.month_name(),
    year=w_ld_2024['time'].dt.year,
    day=w_ld_2024['time'].dt.day,
    day_of_week=w_ld_2024['time'].dt.day_name())

w_pz_2004 = w_pz_2004.assign(
    month=w_pz_2004['time'].dt.month_name(),
    year=w_pz_2004['time'].dt.year,
    day=w_pz_2004['time'].dt.day,
    day_of_week=w_pz_2004['time'].dt.day_name()) 

w_pz_2024 = w_pz_2024.assign(
    month=w_pz_2024['time'].dt.month_name(),
    year=w_pz_2024['time'].dt.year,
    day=w_pz_2024['time'].dt.day,
    day_of_week=w_pz_2024['time'].dt.day_name())

# %% [markdown]
# #### Obliczenie prędkości wiatru ze zmiennych u10 & v10 ze wzoru tj z równania pitagorasa
# - zmienna u10 => prędkość wiatru zachodniego
# - zmienna v10 => prędkość wiartu północnego
#
# $$
# v_w = \sqrt{u_{10}^2 + v_{10}^2}
# $$

# %%
# przeliczenie prędkości wiatru 'v_w' dla wszyskich DataFrame pogodowych i dodanie jako nowa kolumna z tymi wartościami

w_ld_2004['v_w'] = np.sqrt(w_ld_2004['u10']**2 + w_ld_2004['v10']**2)
w_ld_2024['v_w'] = np.sqrt(w_ld_2024['u10']**2 + w_ld_2024['v10']**2)
w_pz_2004['v_w'] = np.sqrt(w_pz_2004['u10']**2 + w_pz_2004['v10']**2)
w_pz_2024['v_w'] = np.sqrt(w_pz_2024['u10']**2 + w_pz_2024['v10']**2)

# %%
# ułożenie kolejnosci kolumn [info data | zmienne pogodowe] 

col_order = ['city','time','year','month','day','day_of_week','u10', 'v10','v_w','t2m','blh','sp','tcc']
w_ld_2004 = w_ld_2004[col_order]
w_ld_2024 = w_ld_2024[col_order]
w_pz_2004 = w_pz_2004[col_order]
w_pz_2024 = w_pz_2024[col_order]

# %% [markdown]
# ####  1.1.3. Połaczenie wszystkich Data Frame w jeden pogodowy

# %%
w_df = pd.concat([w_ld_2004,w_ld_2024,w_pz_2004,w_pz_2024], axis=0 , ignore_index=True)

# %% [markdown]
# ## PODSUMOWANIE PKT. 1.1 DANE POGOWE
# OPIS ZMIENNYCH
# - 'city' -> MIASTO ZAPISANE W SYMOBOLEM
#     - PZ = Poznań
#     - LD = Łódź
# - 'time'............ DATA GODZINA
# - 'year'............ ROK
# - 'month'............MIESIĄC
# - 'day'..............DZIEŃ
# - 'day_of_week -> NAZWA DNIA TYGODNIA
# - 'u10' -> predkosc wiatru z kierunku  ????
# - 'v10' -> prędkość wiatru z kierunku ????
# - 'v_w' -> rzeczywista prędkość wiatru
# - 't2m' -> temperatura powietrze 2m nad poziomem powierzchni
# - 'blh' -> WYSOKOŚĆ WARSTWY GRANICZNEJ
# - 'sp' -> CIŚNIENIE
# - 'tcc' -> CAŁKOWITE ZACHMURZENIE

# %% [markdown]
# ### 1.2. TABELE CAŁKOWITE OPADY - total_precipition

# %% [markdown]
# ##### 1.2.1. Import wszyskich plików do odpowiednich zmiennych

# %%
tp_ld_2004 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/total_precipitation_ld_2004.csv')
tp_ld_2024 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/total_precipitation_ld_2024.csv')
tp_pz_2004 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/total_precipitation_pz_2004.csv')
tp_pz_2024 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/total_precipitation_pz_2024.csv')

# %%
# szybkie sprawdznie 

print(tp_ld_2004.info())

print('^'*140)

display(tp_ld_2004.head(10))
# display(tp_ld_2024.head(2))
# display(tp_pz_2004.head(2))
# display(tp_pz_2024.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8796 entries, 0 to 8795
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8796 non-null   int64
#  1   time        8796 non-null   object
#  2   step        8796 non-null   object
#  3   latitude    8796 non-null   float64
#  4   longitude   8796 non-null   float64
#  5   number      8796 non-null   int64
#  6   surface     8796 non-null   float64
#  7   valid_time  8796 non-null   object
#  8   tp          8784 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 618.6+ KB
# None
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    Unnamed: 0                 time             step  latitude  longitude  \
# 0           0  2003-12-31 18:00:00  0 days 01:00:00     51.75       19.5
# ...

# %% [markdown]
# ####  1.2.2. Połaczenie wszystkich Data Frame w jeden pogodowy

# %%
tp_df = pd.concat([tp_ld_2004,tp_ld_2024,tp_pz_2004,tp_pz_2024], axis=0 , ignore_index=True).reset_index()

# %% [markdown]
# #### 1.2.3. - Agregacja danych do postaci uniwersalnego DataFrame

# %%
# usuwamy zbedne kolumny, nie potrzebne do analizy i dalszej agregacji 

tp_df = tp_df.drop(['Unnamed: 0','time','step','number','surface','index'], axis=1)

# %%
# Zamiana kolumn z data i czasem na typ danych date_time

tp_df['valid_time'] =  tp_df['valid_time'].apply(pd.to_datetime)

# Usuwamy niepotrzebne punkty pomiarowe z innych godzin 'valid_time' niż 00:00, 06:00, 12:00, 18:00 każdego dnia

tp_df = tp_df[tp_df['valid_time'].dt.hour.isin([0, 6, 12, 18])]

# zamieniamy nazwę valid_time na time , aby pasowała do poprzedniego DataFrame dane pogodowe i mozliwosci ich połaczenia

tp_df = tp_df.rename(columns={'valid_time':'time'})

# %%
# sprawedzenie wartosci longitude dla wybranych miast 
tp_df['longitude'].unique()
# Out:
# array([19.5, 17. ])

# %%
# przypisanie skrótu miasta w nowej kolumnie 'city' + usuniecie niepotrzebnej kolu

tp_df['city'] = tp_df['longitude'].map({17.0 : 'PZ' , 19.5 : 'LD'})

# %% [markdown]
# #### 1.2.4. PODSUMOWANIE PKT. 1.2. CAŁKOWITE OPADY
# OPIS ZMIENNYCH
# - 'PZ' -> MIASTO ZAPISANE W SYMOBOLEM
#     - PZ = Poznań
#     - LD = Łódź
# - 'time'............ DATA GODZINA
# - 'tp' -> CAŁKOWITE OPADY

# %% [markdown]
# ## 1.3. TABELE INWERSJE - inwesrsja[..].csv

# %% [markdown]
# #### 1.3.1. Import wszystich plikow do odpowiednich zmienych

# %%
i_ld_2004 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/inwersja_ld_2004.csv')
i_ld_2024 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/inwersja_ld_2024.csv')
i_pz_2004 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/inwersja_pz_2004.csv')
i_pz_2024 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/inwersja_pz_2024.csv')

# %%
# szybkie sprawdzenie 

print(i_ld_2004.info())

print('^'*140)

display(i_ld_2004.head(2))
display(i_ld_2024.head(2))
display(i_pz_2004.loc[i_pz_2004['time']=='2004-04-23 18:00:00'])
display(i_pz_2024.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1464 entries, 0 to 1463
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1464 non-null   int64
#  1   time           1464 non-null   object
#  2   t_925          1464 non-null   float64
#  3   t_1000         1464 non-null   float64
#  4   t_delta        1464 non-null   float64
#  5   inversion_0/1  1464 non-null   int64
#  6   data           1464 non-null   object
#  7   city           1464 non-null   object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 91.6+ KB
# None
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    Unnamed: 0                 time      t_925     t_1000   t_delta  \
# 0           0  2004-01-01 00:00:00  268.93994  272.32153  3.381592
# 1           1  2004-01-01 06:00:00  268.31910  271.23560  2.916504
#
# ...

# %% [markdown]
# #### 1.3.1. Łaczymy wszyskie datasety z inwesja w jeden DataFrame

# %%
i_df = pd.concat([i_ld_2004, i_ld_2024, i_pz_2004, i_pz_2024],  axis=0, ignore_index=True)

# %%
# usuwamy nie potrzebne kolumny do dalszej analizy

# %%
# Zmieniamy wartości kolumny 'city' z ld na LD oraz NaN na PZ. wg sprawdzenia zainportowanych datasetów 
# wyniki, że dane dla poznania 2004 oraz 2024 nie miały dodanych wartosci city , należy to teraz uzupełnić 

# i_df['city'] = i_df['city'].fillna('PZ')
i_df['city'] = i_df['city'].map(lambda c: c.upper() if c == 'ld' else 'PZ')

# %%
# usuwamy nie potrzebne kolumny do dalszej analizy 

i_df = i_df.drop(['Unnamed: 0', 't_925','t_1000','t_delta','data'],axis=1)

# %%
# Sprawdzenie poprawnosci inwersja_DataFrame gotowego do megre do głwnego DataFrame

display(i_df.head())
print('^' * 140) 
display(i_df['city'].unique())
display(i_df['inversion_0/1'].unique())
print('^' * 140) 
display(i_df.info())
# Out:
#                   time  inversion_0/1 city
# 0  2004-01-01 00:00:00              1   LD
# 1  2004-01-01 06:00:00              1   LD
# 2  2004-01-01 12:00:00              1   LD
# 3  2004-01-01 18:00:00              1   LD
# 4  2004-01-02 00:00:00              1   LD
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# array(['LD', 'PZ'], dtype=object)
# array([1, 0])
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5856 entries, 0 to 5855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           5856 non-null   object
#  1   inversion_0/1  5856 non-null   int64
#  2   city           5856 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 137.4+ KB
# ...

# %% [markdown]
# #### 1.3.2. PODSUMOWANIE PKT. 1.3. Inwersje
# OPIS ZMIENNYCH
# - 'PZ' -> MIASTO ZAPISANE W SYMOBOLEM
#     - PZ = Poznań
#     - LD = Łódź
# - 'time'............ DATA GODZINA
# - 'inverion_0/1' -> inwersja_0 = NIE MA / inwerja_1 = JEST

# %% [markdown]
# ## 1.4. DANE PM2.5 - dane_pm25_ld_pz_2024.csv

# %%
pm25_2024 = pd.read_csv('/Users/marcinurbanski/Desktop/jmu_repo/1_projekt_air_polution_repo/0_ready_raw_data/dane_pm25_ld_pz_2024.csv')

# %%
pm25_2024.head()
# Out:
#    Unnamed: 0            Date_time  LdLodzCzerni  WpPoznDabrow  WpPoznSzwajc
# 0           5  2024-01-01 01:00:00          43.2          41.3          67.9
# 1           6  2024-01-01 02:00:00          39.2          38.4          88.7
# 2           7  2024-01-01 03:00:00          39.2          25.8          84.6
# 3           8  2024-01-01 04:00:00          40.2          16.3          75.8
# 4           9  2024-01-01 05:00:00          40.2          12.6          50.8

# %% [markdown]
# ### 2.0. łaczenie danych pogodowych oraz danych całkowitych opadów do jednego DataFrame.
# DANE_POGODOWE + DANE_CAŁKOWITYCH OPADÓW => w_tp_df

# %%
# łaczymy metoda 'left' 

w_tp_df = w_df.merge(tp_df, on=['time','city'], how='left')

# %%
w_tp_df.head()
# Out:
#   city                time  year    month  day day_of_week       u10  \
# 0   LD 2004-01-01 00:00:00  2004  January    1    Thursday  0.794144
# 1   LD 2004-01-01 06:00:00  2004  January    1    Thursday  0.833252
# 2   LD 2004-01-01 12:00:00  2004  January    1    Thursday  0.560913
# 3   LD 2004-01-01 18:00:00  2004  January    1    Thursday  1.766174
# 4   LD 2004-01-02 00:00:00  2004  January    2      Friday  2.470276
#
#         v10       v_w        t2m        blh        sp       tcc  latitude  \
# 0 -3.466965  3.556755  272.89502  413.98730  99670.00  0.989990     51.75
# 1 -3.170166  3.277844  271.41577  404.84766  99482.06  0.983978     51.75
# 2 -3.819946  3.860908  271.91187  549.08154  99248.31  0.733307     51.75
# 3 -2.887283  3.384638  270.11084  382.47217  99025.31  0.713409     51.75
# 4 -2.238907  3.333912  270.04688  454.67480  98845.00  0.838318     51.75
#
#    longitude        tp
# 0       19.5  0.000080
# 1       19.5  0.000015
# 2       19.5  0.000064
# ...
