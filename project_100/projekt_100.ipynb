# %% [markdown]
# # GlobalTrade sp. z o.o.
# Firma sprzedażowa
# Dane pochodzą z różnych systemów:
# + CRM (klienci – CSV)
# + ERP (produkty – Excel)
# + System sprzedażowy (sprzedaż – CSV + SQL)
# + System magazynowy (stany – CSV + SQL)

# %% [markdown]
# #### IMPORTY BIBLIOTEK DO PROJEKTU

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install ydata-profiling
from ydata_profiling import ProfileReport
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (3.9.2)
# Requirement already satisfied: pydantic<3,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (2.8.2)
# Collecting PyYAML<6.1,>=6.0.3 (from ydata-profiling)
#   Downloading pyyaml-6.0.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (1.26.4)
# Collecting minify-html>=0.15.0 (from ydata-profiling)
#   Downloading minify_html-0.18.1-cp312-cp312-macosx_10_12_x86_64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling)
#   Downloading phik-0.12.5-cp312-cp312-macosx_10_13_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (0.14.2)
# Collecting typeguard<5,>=4 (from ydata-profiling)
#   Downloading typeguard-4.5.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.2 (from ydata-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata-profiling)
#   Downloading wordcloud-1.9.6-cp312-cp312-macosx_10_13_x86_64.whl.metadata (3.4 kB)
# Collecting dacite<2,>=1.9 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<0.63,>=0.60 in /opt/anaconda3/lib/python3.12/site-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /opt/anaconda3/lib/python3.12/site-packages (from imagehash==4.3.2->ydata-profiling) (1.7.0)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.12/site-packages (from imagehash==4.3.2->ydata-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/lib/python3.12/site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /opt/anaconda3/lib/python3.12/site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.1.31)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Collecting typing-extensions>=4.6.1 (from pydantic<3,>=2->ydata-profiling)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /opt/anaconda3/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.3)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-2.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp312-cp312-macosx_10_12_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp312-cp312-macosx_10_13_x86_64.whl (671 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.7/671.7 kB 4.0 MB/s eta 0:00:00
# Downloading pyyaml-6.0.3-cp312-cp312-macosx_10_13_x86_64.whl (182 kB)
# Downloading typeguard-4.5.1-py3-none-any.whl (36 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading wordcloud-1.9.6-cp312-cp312-macosx_10_13_x86_64.whl (170 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading puremagic-2.0.0-py3-none-any.whl (65 kB)
# Installing collected packages: minify-html, filetype, typing-extensions, PyYAML, puremagic, multimethod, dacite, typeguard, imagehash, wordcloud, visions, phik, ydata-profiling
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
# Successfully installed PyYAML-6.0.3 dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 minify-html-0.18.1 multimethod-1.12 phik-0.12.5 puremagic-2.0.0 typeguard-4.5.1 typing-extensions-4.15.0 visions-0.8.1 wordcloud-1.9.6 ydata-profiling-4.18.1

# %%
jmu_path = '/Users/marcinurbanski/Desktop/jmu_repo/projekt_100'

# %%
os.getcwd()
# Out:
# '/Users/marcinurbanski/Desktop/jmu_repo/projekt_100'

# %% [markdown]
# ### Dane :

# %% [markdown]
# #### 1. Sales -> z pliku sales.csv

# %%
sales_csv = pd.read_csv(jmu_path + '/sales.csv',delimiter=',')

# %%
sales_df = pd.DataFrame(sales_csv)

sales_df_sorted = sales_df.sort_values(by='product_id')
sales_df_sorted.head(2)
# Out:
#      sale_id  customer_id  product_id  quantity   sale_date  total_value
# 198      199          107           1         4  2023-03-04         4368
# 52        53          119           1        18  2023-10-08        19656

# %% [markdown]
# #### 2. Customers -> from .cvs plik

# %%
customers_csv = pd.read_csv(jmu_path+'/customers.csv',delimiter=',')
customers_df = pd.DataFrame(customers_csv)
# customers_df.head()

# %% [markdown]
# #### 3. inventory -> from .csv plik

# %%
inventory_csv = pd.read_csv(jmu_path + '/inventory.csv',delimiter = ',')
inventory_df = pd.DataFrame(inventory_csv)
inventory_df.head(2)
# Out:
#    product_id warehouse  stock_level last_update
# 0           1        W2           61  2024-01-01
# 1           2        W2           83  2024-01-04

# %% [markdown]
# #### 4. Products -> from .xlsx plik

# %%
products_xlsx = pd.read_excel(jmu_path + '/products.xlsx')
products_df = pd.DataFrame(products_xlsx)
products_df.head(2)
# Out:
#    product_id product_name   category  unit_price
# 0           1    Product_1  Furniture        1092
# 1           2    Product_2       Food          36

# %% [markdown]
# #### 5. DANE .db sales

# %%
# %reload_ext sql

# %%
# %sql sqlite:///Desktop/jmu_repo/projekt_100/sales.db
# Out:
# (sqlite3.OperationalError) unable to open database file
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
#
# SELECT * FROM sales
# limit 2
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ## Zadania do wykonania :

# %% [markdown]
# ## 1. Monthly Sales
#     1.1.  - total sales by months
#         1.1.1 - agrekacja total_value per miesiac [pandas]
#         1.1.1 - wykres liniowy [matplotlib]
#     1.2.  - Sales by months cumulatively

# %%
print(sales_df.head())
print(sales_df.info())
# Out:
#    sale_id  customer_id  product_id  quantity   sale_date  total_value
# 0        1           92           8        13  2023-02-26        18408
# 1        2          113          65         1  2023-08-06         1135
# 2        3           56          57         6  2023-12-27          234
# 3        4          117         119        19  2023-07-23        10108
# 4        5          134          67        16  2023-05-30        13648
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sale_id      500 non-null    int64
#  1   customer_id  500 non-null    int64
#  2   product_id   500 non-null    int64
#  3   quantity     500 non-null    int64
#  4   sale_date    500 non-null    object
#  5   total_value  500 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 23.6+ KB
# None

# %% [markdown]
# #### OPERACJA_1 :
# + konwersja kolumnny 'sale_date' z str na timestamp
# + dodanie kolumny 'sale_month' na podstawie kolumny 'sale_date'

# %%
sales_df['sale_date'] = pd.to_datetime(sales_df['sale_date'])

# %%
sales_df['sale_month'] = sales_df['sale_date'].dt.month

# %%
#sales_df.head()

# %%
sale_by_month = sales_df.groupby('sale_month',as_index = False).sum('total_value')
sale_by_month
# Out:
#     sale_month  sale_id  customer_id  product_id  quantity  total_value
# 0            1    15982         4583        4314       613       497866
# 1            2    11722         3975        2735       435       293138
# 2            3    13980         4367        3802       631       420570
# 3            4    18284         4791        4208       708       607548
# 4            5    15448         4420        3590       526       443598
# 5            6     8422         2371        1929       366       314157
# 6            7     4336         1714        1095       268       191401
# 7            8     6637         1730        1805       214       197663
# 8            9     6853         2431        1667       277       232548
# 9           10     7846         2197        1762       346       280632
# 10          11     6821         2388        2030       333       253298
# 11          12     8919         2522        1899       333       283375

# %% [markdown]
# #### OPERACJA_2 :
# - Presents reloult as line graph
# - formating plot

# %%
plt.figure(figsize=[12,4]) # created plot horysontal with proportion 12:4
plt.plot(sale_by_month['sale_month'],sale_by_month['total_value'],marker='.',ms=10,color='white') 
plt.title('ZAD_1 - Total Sales by Month',size=20)

plt.xticks(sale_by_month['sale_month'])
plt.yticks([200000,300000,400000,500000,600000],['2k','3k','4k','5k','6k'])
#plt.yticks(range(200000,800000,100000))

plt.xlabel('Months',loc='center',size=20,color= 'green')
plt.ylabel('Total_value',loc='center',size=20,color='green')

plt.grid()

ax = plt.gca()
ax.set_facecolor('#009688')

plt.show()

# %% [markdown]
# ### 1.2. Sales by months cumulatively
#     1.2.1. - Created 'year_month' column
#     1.2.2. - Line Graph monthly Sales
#     1.2.3. - Best & Worst Sale Month

# %%
sales_df['year_month'] = sales_df['sale_date'].dt.to_period('M')

# %%
sales_df.head()
# Out:
#    sale_id  customer_id  product_id  quantity  sale_date  total_value  \
# 0        1           92           8        13 2023-02-26        18408
# 1        2          113          65         1 2023-08-06         1135
# 2        3           56          57         6 2023-12-27          234
# 3        4          117         119        19 2023-07-23        10108
# 4        5          134          67        16 2023-05-30        13648
#
#    sale_month year_month
# 0           2    2023-02
# 1           8    2023-08
# 2          12    2023-12
# 3           7    2023-07
# 4           5    2023-05

# %%
sale_by_ym = sales_df.groupby(sales_df['year_month'],as_index=False).sum('total_value')

# %%
sale_by_ym['year_month'] = sale_by_ym['year_month'].dt.to_timestamp()

# %%
#sale_by_ym

# %% [markdown]
# #### 1.2.2. Line Graph monthly Sales

# %%
plt.figure(figsize=[16,6])

plt.plot(sale_by_ym['year_month'],sale_by_ym['total_value'],marker='o',color='white')
plt.title('Line Graph by Year&Month Cumulatively',size=20)
plt.xticks(sale_by_ym['year_month'],['2023-01','2023-02','2023-03','2023-04','2023-05','2023-06','2023-07','2023-08','2023-09',
                                     '2023-10','2023-11','2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-01'],rotation=45)
plt.yticks([200000,300000,400000],['2k','3k','4k'])
#plt.yticks(range(200000,800000,100000))

plt.xlabel('Year-Months',loc='center',size=20,color= 'green')
plt.ylabel('Value',loc='center',size=20,color='green')

ax = plt.gca() # pobiera aktulana oś
ax.set_facecolor('#009280') # ustawienie koloru tła 

plt.grid()
plt.show()

# %% [markdown]
# #### 1.2.3 Best & Worst Sale Month

# %%
best_sale_ym_value = sale_by_ym['total_value'].max()
worst_sale_ym_value = sale_by_ym['total_value'].min()
best_sale_year_month = sale_by_ym.loc[sale_by_ym['total_value'] == best_sale_ym_value,'year_month'].iloc[0]
worst_sale_year_month = sale_by_ym.loc[sale_by_ym['total_value'] == worst_sale_ym_value,'year_month'].iloc[0]

print(f'The best sale was in month:  {best_sale_year_month}, and it was,{6*' '} {best_sale_ym_value} \n\nThe worst sale was in month: {worst_sale_year_month}, and it was,{5*' ' } {worst_sale_ym_value}')
# Out:
# The best sale was in month:  2023-04-01 00:00:00, and it was,       364362
#
# The worst sale was in month: 2024-06-01 00:00:00, and it was,      103119

# %% [markdown]
# ## 2. TOP 10 products by total_value
#
# - join sales + produckts data, merge two data sets
# - grupby products agragation
# - barplot for visualization

# %%
# sales_df.head()

# %%
# products_df.head()

# %% [markdown]
# #### 2.1. Merge two data sets 'Sales.csv' & 'Products.xlsx'

# %%
merged_s_p = sales_df.merge(products_df,on='product_id',how='left')
merged_s_p.sort_values('product_id')
# Out:
#      sale_id  customer_id  product_id  quantity  sale_date  total_value  \
# 198      199          107           1         4 2023-03-04         4368
# 52        53          119           1        18 2023-10-08        19656
# 51        52            5           2         4 2024-05-20          144
# 58        59           85           2         1 2023-11-18           36
# 148      149           61           2         8 2023-12-26          288
# ..       ...          ...         ...       ...        ...          ...
# 306      307           78         120         5 2023-03-27         4105
# 359      360           38         120        10 2023-08-20         8210
# 415      416          122         120        17 2024-06-20        13957
# 440      441           63         120        12 2023-01-26         9852
# 24        25          144         120        18 2024-06-09        14778
#
#      sale_month year_month product_name   category  unit_price
# 198           3    2023-03    Product_1  Furniture        1092
# 52           10    2023-10    Product_1  Furniture        1092
# 51            5    2024-05    Product_2       Food          36
# 58           11    2023-11    Product_2       Food          36
# 148          12    2023-12    Product_2       Food          36
# ..          ...        ...          ...        ...         ...
# 306           3    2023-03  Product_120       Food         821
# 359           8    2023-08  Product_120       Food         821
# 415           6    2024-06  Product_120       Food         821
# 440           1    2023-01  Product_120       Food         821
# 24            6    2024-06  Product_120       Food         821
#
# [500 rows x 11 columns]

# %%
gr_merged_s_p = merged_s_p.groupby('product_name',as_index=False).sum('total_value')
top_10 = gr_merged_s_p.sort_values('total_value',ascending=False).head(10)
top_10 = top_10.reset_index()[['total_value','quantity','product_name','product_id','unit_price']]
top_10
# Out:
#    total_value  quantity product_name  product_id  unit_price
# 0       129739       137   Product_25         250        9470
# 1       119610       135   Product_98        1274       11518
# 2       108504        99   Product_87         783        9864
# 3        93585        85  Product_109         763        7707
# 4        86020        85   Product_85         510        6072
# 5        85484        71   Product_26         182        8428
# 6        78771        77   Product_88         616        7161
# 7        76050        65  Product_114         570        5850
# 8        74800        88  Product_108         756        5950
# 9        73254        87   Product_99         891        7578

# %%
plt.figure(figsize = [16,9])

plt.bar(top_10['product_name'],top_10['total_value'],color='#478e82')
plt.title('TOP 10 Product by Sales',size=30)
plt.xticks(rotation = 90,size=15)
plt.yticks(size=15)

plt.grid()
plt.show()

# %% [markdown]
# #### Eksport tabeli top 10 do excela

# %%
top_10.to_excel('/Users/marcinurbanski/Desktop/top_10_products.xlsx',index=False)

# %%
os.getcwd()
# Out:
# '/Users/marcinurbanski/Desktop/jmu_repo/projekt_100'

# %% [markdown]
# ## 3. Sales by Customers
#     3.1. - Percentage share od 'Segments'
#     3.2. - Pie Chart

# %% [markdown]
# ### 3.1. - Percentage share od 'Segments'

# %%
mer_sal_cust = customers_df.merge(sales_df, on='customer_id',how='left')

# %%
grouped_segment_count = mer_sal_cust.groupby(by='segment',as_index=False,dropna=False).count()[['segment','customer_id']]
grouped_segment_count['percentage_share'] = round(grouped_segment_count['customer_id'] / grouped_segment_count['customer_id'].sum() * 100,1)
grouped_segment_count
# Out:
#      segment  customer_id  percentage_share
# 0     Retail          160              31.8
# 1        VIP          185              36.8
# 2  Wholesale          158              31.4

# %% [markdown]
# #### 3.2. Pie Chart

# %%
plt.pie(grouped_segment_count['customer_id'],labels = grouped_segment_count['segment'],autopct='%1.1f%%')
plt.title('Percentage share of customer segments')

plt.show()

# %% [markdown]
# ## 4. Top 15 customers
#     3.1. - Sum of sale by customer
#     3.2. - Ranking table
#     3.3. - .csv export

# %% [markdown]
# ### 4.1. Sum of sale by customer

# %%
# customers_df.head()

# %%
# sales_df.head()

# %%
merged_sale_customer_df = customers_df.merge(sales_df,on='customer_id',how='left')[['customer_id','customer_name','total_value']]
# merged_sale_customer_df.head()

# %%
gr_top_15_customers =  merged_sale_customer_df.groupby(by = ['customer_id','customer_name'],as_index = False).sum('total_value')
top_15_customers = gr_top_15_customers.sort_values('total_value',ascending=False)[0:15].reset_index()
type(top_15_customers)
top_15_customers
# Out:
#     index  customer_id customer_name  total_value
# 0     103          104    Client_104      93541.0
# 1       0            1      Client_1      87496.0
# 2      91           92     Client_92      80946.0
# 3      62           63     Client_63      75162.0
# 4      46           47     Client_47      71021.0
# 5      94           95     Client_95      68219.0
# 6     131          132    Client_132      65651.0
# 7     117          118    Client_118      64146.0
# 8     114          115    Client_115      59055.0
# 9     110          111    Client_111      58835.0
# 10     37           38     Client_38      53736.0
# 11      5            6      Client_6      51079.0
# 12     77           78     Client_78      50715.0
# 13     13           14     Client_14      50590.0
# 14    116          117    Client_117      50012.0

# %% [markdown]
# ### 4.2. Avarage of total_values of all customers

# %%
# merged_sale_customer_df.info()

# %%
mean_value_by_customer = round(merged_sale_customer_df['total_value'].mean(),0)

print(f'The mean total value by all custeomers is : \n\033[1M{mean_value_by_customer}\033[0M')

# \033[1M -> WŁACZA BOLD \033[0M' --> RESETUJE STYL
# Out:
# The mean total value by all custeomers is :
# 8032.0

# %% [markdown]
# ### 4.3. Bar Plot for Top 15 customers + mean value of all

# %%
columns_top15 = ['customer_name','total_value']
top_15_customers.to_csv('/Users/marcinurbanski/jmu_projekt_100/top_15_customers.csv',index=False, sep=';',columns=columns_top15)

# %%
plt.figure(figsize=[16,6])


plt.bar(top_15_customers['customer_name'],top_15_customers['total_value'])
plt.axhline(mean_value_by_customer, color='red')

plt.title('Top 15 Customers', size = 40)
plt.xlabel('Customer Names', size = 20)
plt.ylabel('Value', size = 20) 
# ......... DOPRACOWAĆ  WIZUALNY EFEKT WYKRESU 
plt.xticks(rotation = 90, size = 15) 
plt.grid()
plt.show()

# %% [markdown]
# ## 5. Best & Worst sale month
#     - Trend analysis of all months
#     - Identification of Extrema
#     - Comment

# %%
# sales_df

# %%
plt.figure(figsize=(15,5))
plt.hist(sales_df['total_value']/1000,bins=5,color='#034994',edgecolor='white',label='value|1:1000|')
plt.hist(sales_df['quantity'],color='lightblue',edgecolor='white',label='quantity|1:1|')
plt.title('Histogeram of Value adn Quantity',size=25)
plt.grid(axis='y')
plt.legend()
plt.show()

# %%
[sale_by_ym['total_value'].max()]
# Out:
# [364362]

# %%
str(sale_by_ym.loc[sale_by_ym['total_value']==sale_by_ym['total_value'].max(),'year_month'].iloc[0])[0:7]
# Out:
# '2023-04'

# %%
print(f'Najniższ sprzedaż odbyła się w miesiacu : {str(sale_by_ym.loc[sale_by_ym['total_value']==sale_by_ym['total_value'].min(),'year_month'].iloc[0])[0:7]} i wynosiła : {sale_by_ym['total_value'].min()} \nNajwyższa sprzdaż odbyła się w miesiacu : {str(sale_by_ym.loc[sale_by_ym['total_value']==sale_by_ym['total_value'].max(),'year_month'].iloc[0])[0:7]} i wynosiła : {sale_by_ym['total_value'].max()}')
# Out:
# Najniższ sprzedaż odbyła się w miesiacu : 2024-06 i wynosiła : 103119
# Najwyższa sprzdaż odbyła się w miesiacu : 2023-04 i wynosiła : 364362

# %%
sale_by_ym['percante_change_method'] = round(sale_by_ym['total_value'].pct_change() * 100,2)
sale_by_ym_prc_change = sale_by_ym[['year_month','percante_change_method']]

# %%
sale_by_ym_prc_change
# Out:
#    year_month  percante_change_method
# 0  2023-01-01                     NaN
# 1  2023-02-01                  -57.57
# 2  2023-03-01                   38.37
# 3  2023-04-01                  107.93
# 4  2023-05-01                  -39.72
# 5  2023-06-01                   -3.92
# 6  2023-07-01                   -9.30
# 7  2023-08-01                    3.27
# 8  2023-09-01                   17.65
# 9  2023-10-01                   20.68
# 10 2023-11-01                   -9.74
# 11 2023-12-01                   11.87
# 12 2024-01-01                  -29.64
# 13 2024-02-01                  -16.50
# 14 2024-03-01                   47.35
# 15 2024-04-01                   -0.88
# 16 2024-05-01                   -7.91
# 17 2024-06-01                  -53.95

# %%
plt.figure(figsize = (15,5))
plt.plot(sale_by_ym_prc_change['year_month'],sale_by_ym_prc_change['percante_change_method'],color='white')
plt.xticks(sale_by_ym['year_month'],['2023-01','2023-02','2023-03','2023-04','2023-05','2023-06','2023-07','2023-08','2023-09',
                                     '2023-10','2023-11','2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-01'],rotation=45)

plt.title('Line Graph presents PERCENTE CHANGE of total_value compere to previous month', size=20)
ax = plt.gca() # pobiera aktulana oś - zwraca aktualny obiekt osi ,dziecz czemy może modyfikowć wykres po jego narysowaniu.
ax.set_facecolor('#616992') # ustawienie koloru tła 

plt.grid(axis='x')
plt.show()

# %% [markdown]
# ### 5.3. Bar plot of    'values / year months' ---> with Trend line <---
#
#
# ---- > do uzupełnienia < -----

# %% [markdown]
# ### 5.4. Comment
#
# ---- > do uzupełnienia < -----

# %% [markdown]
# ## 6. Sales by Country
#
#     - merge two datasets sales + customers
#     - agregation by countries/regions
#     - bar plot

# %% [markdown]
# ### 6.1 Sorted Table of sales by each country

# %%
# customers_df.tail()

# %%
# sales_df.tail()

# %%
sales_customer_df = sales_df.merge(customers_df,how='left')

# sales_customer_df

# %%
sales_gr_country = sales_customer_df.groupby(sales_customer_df['country'],as_index=False).sum('total_value')[['country','quantity','total_value']]
sales_gr_country = sales_gr_country.sort_values('total_value',ascending=False)


sales_gr_country.style.format({"total_value": "{:,}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_47cda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47cda_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_47cda_level0_col1" class="col_heading level0 col1" >quantity</th>
#       <th id="T_47cda_level0_col2" class="col_heading level0 col2" >total_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47cda_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_47cda_row0_col0" class="data row0 col0" >SK</td>
#       <td id="T_47cda_row0_col1" class="data row0 col1" >1668</td>
#       <td id="T_47cda_row0_col2" class="data row0 col2" >1,315,944</td>
#     </tr>
#     <tr>
#       <th id="T_47cda_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_47cda_row1_col0" class="data row1 col0" >CZ</td>
#       <td id="T_47cda_row1_col1" class="data row1 col1" >1417</td>
#       <td id="T_47cda_row1_col2" class="data row1 col2" >1,112,383</td>
#     </tr>
#     <tr>
#       <th id="T_47cda_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_47cda_row2_col0" class="data row2 col0" >DE</td>
#       <td id="T_47cda_row2_col1" class="data row2 col1" >1038</td>
#       <td id="T_47cda_row2_col2" class="data row2 col2" >830,371</td>
#     </tr>
#     <tr>
#       <th id="T_47cda_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_47cda_row3_col0" class="data row3 col0" >PL</td>
#       <td id="T_47cda_row3_col1" class="data row3 col1" >927</td>
#       <td id="T_47cda_row3_col2" class="data row3 col2" >757,096</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 6.2. Bar plot

# %%
sns.set(style="darkgrid",palette='deep')

sns.barplot(x=sales_gr_country['country'],y=sales_gr_country['total_value'],hue=sales_gr_country['country'],palette='pastel')
plt.title('Sale by country [ sorted ]',size=25)
plt.show()

# %% [markdown]
# # 7. Products with Low Stock & High Sales
#  - MERGE DATASETS : sales_df & inventory_df
#  - Compere stock and probable demand
#  - Recomendation list

# %%
#sales_df.loc[sales_df['sale_id']==3]

# %%
#inventory_df.head()

# %%
# concut two datasets 'sales_df' and 'inventory_df' by product_id and agregated sum by 'quantity'
# also short df to three columns  


sale_invt_df = sales_df.merge(inventory_df,on='product_id')
sale_invt_gr = sale_invt_df.groupby(by='product_id',as_index=False).agg({'quantity': 'sum',
                                                                         'customer_id': 'count'})

#sale_invt_gr = sale_invt_gr.sort_values(by=['stock_level','quantity'])[['product_id','quantity','stock_level']]
#sale_invt_gr

# %%
sum_qun_i_stock_gr = sale_invt_gr.merge(inventory_df,on='product_id')

# %% [markdown]
# ### 7.1. List of 10 product_id with the lowest stock_level compare to sale

# %%
# create new collumn to present deference in stock_level and double quantity sale , to show what was the sale 
# of each product and what is current stock level. 

sum_qun_i_stock_gr['sold_quantity/stock'] = sum_qun_i_stock_gr['stock_level'] - sum_qun_i_stock_gr['quantity']

# %%
df_71 = sum_qun_i_stock_gr.loc[sum_qun_i_stock_gr['sold_quantity/stock']<=100]
df_71 = df_71.sort_values('sold_quantity/stock').head(20)

#df_71

# %%
# new df grouped by product_id and presets latest and newest date of sale
# it will helps me to create a period of time that the whole quantityt of sale was happend of each product id

dates_min_max = sales_df.groupby("product_id")["sale_date"].agg(
    pierwsza="min",
    ostatnia="max"
)
#dates_min_max

# %%
# finding max quantity sale of each product 

max_q = sales_df.groupby(by='product_id',as_index=False).max()[['product_id','quantity']].rename(columns={'quantity' : 'quantity_max'})
#max_q

# %%
# add substract of newest and latest day of sale and create new table column period day of total quantity sales

df_71 = df_71.merge(dates_min_max, how = 'left', on = 'product_id')
df_71['sale_period'] = (df_71['ostatnia']-df_71['pierwsza']).dt.days

# %%
df_71 = df_71[['product_id','quantity','stock_level','sold_quantity/stock','sale_period','customer_id']]

df_71 = df_71.rename(columns={'customer_id' : 'trades_count'},errors="raise")

df_71 = df_71.merge(max_q,how='left',on='product_id')

#df_71

# %%
# add colors and table lines to presetn table in better way 
(
    df_71.style.set_properties(subset=['sale_period','quantity_max','trades_count'], **{'background-color':'orange'})
    .set_properties(subset=['sold_quantity/stock'], **{'background-color':'yellow'})
    .set_properties(subset=['product_id'], **{'background-color':'#89CFF0'})
    .set_table_styles([
        {'selector': 'th', 'props':[('border', '1px solid black')]},
        {'selector': 'td', 'props':[('border', '1px solid black')]}
    ])
)
# Out:
# <style type="text/css">
# #T_9e2de th {
#   border: 1px solid black;
# }
# #T_9e2de td {
#   border: 1px solid black;
# }
# #T_9e2de_row0_col0, #T_9e2de_row1_col0, #T_9e2de_row2_col0, #T_9e2de_row3_col0, #T_9e2de_row4_col0, #T_9e2de_row5_col0, #T_9e2de_row6_col0, #T_9e2de_row7_col0, #T_9e2de_row8_col0, #T_9e2de_row9_col0, #T_9e2de_row10_col0, #T_9e2de_row11_col0, #T_9e2de_row12_col0, #T_9e2de_row13_col0, #T_9e2de_row14_col0, #T_9e2de_row15_col0, #T_9e2de_row16_col0, #T_9e2de_row17_col0, #T_9e2de_row18_col0, #T_9e2de_row19_col0 {
#   background-color: #89CFF0;
# }
# #T_9e2de_row0_col3, #T_9e2de_row1_col3, #T_9e2de_row2_col3, #T_9e2de_row3_col3, #T_9e2de_row4_col3, #T_9e2de_row5_col3, #T_9e2de_row6_col3, #T_9e2de_row7_col3, #T_9e2de_row8_col3, #T_9e2de_row9_col3, #T_9e2de_row10_col3, #T_9e2de_row11_col3, #T_9e2de_row12_col3, #T_9e2de_row13_col3, #T_9e2de_row14_col3, #T_9e2de_row15_col3, #T_9e2de_row16_col3, #T_9e2de_row17_col3, #T_9e2de_row18_col3, #T_9e2de_row19_col3 {
#   background-color: yellow;
# }
# #T_9e2de_row0_col4, #T_9e2de_row0_col5, #T_9e2de_row0_col6, #T_9e2de_row1_col4, #T_9e2de_row1_col5, #T_9e2de_row1_col6, #T_9e2de_row2_col4, #T_9e2de_row2_col5, #T_9e2de_row2_col6, #T_9e2de_row3_col4, #T_9e2de_row3_col5, #T_9e2de_row3_col6, #T_9e2de_row4_col4, #T_9e2de_row4_col5, #T_9e2de_row4_col6, #T_9e2de_row5_col4, #T_9e2de_row5_col5, #T_9e2de_row5_col6, #T_9e2de_row6_col4, #T_9e2de_row6_col5, #T_9e2de_row6_col6, #T_9e2de_row7_col4, #T_9e2de_row7_col5, #T_9e2de_row7_col6, #T_9e2de_row8_col4, #T_9e2de_row8_col5, #T_9e2de_row8_col6, #T_9e2de_row9_col4, #T_9e2de_row9_col5, #T_9e2de_row9_col6, #T_9e2de_row10_col4, #T_9e2de_row10_col5, #T_9e2de_row10_col6, #T_9e2de_row11_col4, #T_9e2de_row11_col5, #T_9e2de_row11_col6, #T_9e2de_row12_col4, #T_9e2de_row12_col5, #T_9e2de_row12_col6, #T_9e2de_row13_col4, #T_9e2de_row13_col5, #T_9e2de_row13_col6, #T_9e2de_row14_col4, #T_9e2de_row14_col5, #T_9e2de_row14_col6, #T_9e2de_row15_col4, #T_9e2de_row15_col5, #T_9e2de_row15_col6, #T_9e2de_row16_col4, #T_9e2de_row16_col5, #T_9e2de_row16_col6, #T_9e2de_row17_col4, #T_9e2de_row17_col5, #T_9e2de_row17_col6, #T_9e2de_row18_col4, #T_9e2de_row18_col5, #T_9e2de_row18_col6, #T_9e2de_row19_col4, #T_9e2de_row19_col5, #T_9e2de_row19_col6 {
#   background-color: orange;
# }
# </style>
# <table id="T_9e2de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e2de_level0_col0" class="col_heading level0 col0" >product_id</th>
#       <th id="T_9e2de_level0_col1" class="col_heading level0 col1" >quantity</th>
#       <th id="T_9e2de_level0_col2" class="col_heading level0 col2" >stock_level</th>
#       <th id="T_9e2de_level0_col3" class="col_heading level0 col3" >sold_quantity/stock</th>
#       <th id="T_9e2de_level0_col4" class="col_heading level0 col4" >sale_period</th>
#       <th id="T_9e2de_level0_col5" class="col_heading level0 col5" >trades_count</th>
#       <th id="T_9e2de_level0_col6" class="col_heading level0 col6" >quantity_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e2de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e2de_row0_col0" class="data row0 col0" >57</td>
#       <td id="T_9e2de_row0_col1" class="data row0 col1" >49</td>
#       <td id="T_9e2de_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_9e2de_row0_col3" class="data row0 col3" >-41</td>
#       <td id="T_9e2de_row0_col4" class="data row0 col4" >355</td>
#       <td id="T_9e2de_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_9e2de_row0_col6" class="data row0 col6" >12</td>
#     </tr>
#     <tr>
#       <th id="T_9e2de_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e2de_row1_col0" class="data row1 col0" >119</td>
#       <td id="T_9e2de_row1_col1" class="data row1 col1" >39</td>
#       <td id="T_9e2de_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_9e2de_row1_col3" class="data row1 col3" >-39</td>
#       <td id="T_9e2de_row1_col4" class="data row1 col4" >170</td>
#       <td id="T_9e2de_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_9e2de_row1_col6" class="data row1 col6" >19</td>
#     </tr>
#     <tr>
#       <th id="T_9e2de_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9e2de_row2_col0" class="data row2 col0" >74</td>
#       <td id="T_9e2de_row2_col1" class="data row2 col1" >27</td>
#       <td id="T_9e2de_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_9e2de_row2_col3" class="data row2 col3" >-23</td>
#       <td id="T_9e2de_row2_col4" class="data row2 col4" >240</td>
#       <td id="T_9e2de_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_9e2de_row2_col6" class="data row2 col6" >13</td>
#     </tr>
#     <tr>
#       <th id="T_9e2de_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9e2de_row3_col0" class="data row3 col0" >30</td>
#       <td id="T_9e2de_row3_col1" class="data row3 col1" >46</td>
#       <td id="T_9e2de_row3_col2" class="data row3 col2" >24</td>
#       <td id="T_9e2de_row3_col3" class="data row3 col3" >-22</td>
#       <td id="T_9e2de_row3_col4" class="data row3 col4" >385</td>
#       <td id="T_9e2de_row3_col5" class="data row3 col5" >4</td>
#       <td id="T_9e2de_row3_col6" class="data row3 col6" >18</td>
#     </tr>
#     <tr>
#       <th id="T_9e2de_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9e2de_row4_col0" class="data row4 col0" >39</td>
#       <td id="T_9e2de_row4_col1" class="data row4 col1" >52</td>
#       <td id="T_9e2de_row4_col2" class="data row4 col2" >38</td>
#       <td id="T_9e2de_row4_col3" class="data row4 col3" >-14</td>
#       <td id="T_9e2de_row4_col4" class="data row4 col4" >467</td>
#       <td id="T_9e2de_row4_col5" class="data row4 col5" >6</td>
#       <td id="T_9e2de_row4_col6" class="data row4 col6" >18</td>
#     </tr>
#     <tr>
#       <th id="T_9e2de_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9e2de_row5_col0" class="data row5 col0" >42</td>
#       <td id="T_9e2de_row5_col1" class="data row5 col1" >52</td>
#       <td id="T_9e2de_row5_col2" class="data row5 col2" >41</td>
#       <td id="T_9e2de_row5_col3" class="data row5 col3" >-11</td>
#       <td id="T_9e2de_row5_col4" class="data row5 col4" >389</td>
#       <td id="T_9e2de_row5_col5" class="data row5 col5" >5</td>
#       <td id="T_9e2de_row5_col6" class="data row5 col6" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9e2de_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9e2de_row6_col0" class="data row6 col0" >8</td>
#       <td id="T_9e2de_row6_col1" class="data row6 col1" >28</td>
#       <td id="T_9e2de_row6_col2" class="data row6 col2" >18</td>
#       <td id="T_9e2de_row6_col3" class="data row6 col3" >-10</td>
#       <td id="T_9e2de_row6_col4" class="data row6 col4" >128</td>
#       <td id="T_9e2de_row6_col5" class="data row6 col5" >3</td>
#       <td id="T_9e2de_row6_col6" class="data row6 col6" >13</td>
#     </tr>
#     <tr>
#       <th id="T_9e2de_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9e2de_row7_col0" class="data row7 col0" >111</td>
#       <td id="T_9e2de_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_9e2de_row7_col2" class="data row7 col2" >57</td>
#       <td id="T_9e2de_row7_col3" class="data row7 col3" >-4</td>
#       <td id="T_9e2de_row7_col4" class="data row7 col4" >445</td>
#       <td id="T_9e2de_row7_col5" class="data row7 col5" >6</td>
#       <td id="T_9e2de_row7_col6" class="data row7 col6" >18</td>
#     </tr>
#     <tr>
#       <th id="T_9e2de_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9e2de_row8_col0" class="data row8 col0" >102</td>
#       <td id="T_9e2de_row8_col1" class="data row8 col1" >21</td>
#       <td id="T_9e2de_row8_col2" class="data row8 col2" >18</td>
#       <td id="T_9e2de_row8_col3" class="data row8 col3" >-3</td>
#       <td id="T_9e2de_row8_col4" class="data row8 col4" >398</td>
#       <td id="T_9e2de_row8_col5" class="data row8 col5" >3</td>
#       <td id="T_9e2de_row8_col6" class="data row8 col6" >13</td>
#     </tr>
#     <tr>
#       <th id="T_9e2de_level0_row9" class="row_heading level0 row9

# %% [markdown]
# ### 7.2. Recomendation
# Acording to the tabele are presented 20 product_id with thle lowest stock_level to the sale quantity sum.
# I decidede to creat a new virable as sold_quantity/stock to have clear information between actual stock_level and history of sale of ech produckt, witch reqiure replenishment of stock.
# Two last columns shows for each product_id what was the whole sales period when thosr sum of quantity was sold and the second one shows what was the highest quantity sale and the last of columns says how many trades were done on ech produckt.
# Those three orange columns presents how popular is each product.
# Compering those numbers we can predict which stock_levels must be

# %% [markdown]
# # 8. Marża i wartość sprzedaży wg kategorii
#     - merge products + sales
#     - compering categories
#     - stacked bar

# %%
# sales_df.head()

# %%
# products_df.head()

# %%
prod_sale_df = products_df.merge(sales_df,on='product_id')[['product_id','product_name','category','quantity','total_value']]
prod_sale_df
# Out:
#      product_id product_name   category  quantity  total_value
# 0             1    Product_1  Furniture        18        19656
# 1             1    Product_1  Furniture         4         4368
# 2             2    Product_2       Food         4          144
# 3             2    Product_2       Food         1           36
# 4             2    Product_2       Food         8          288
# ..          ...          ...        ...       ...          ...
# 495         120  Product_120       Food         3         2463
# 496         120  Product_120       Food         5         4105
# 497         120  Product_120       Food        10         8210
# 498         120  Product_120       Food        17        13957
# 499         120  Product_120       Food        12         9852
#
# [500 rows x 5 columns]

# %%
category_gr = prod_sale_df.groupby(by='category',as_index=True).agg(
    value_sum_1x1000 = ('total_value','sum'),
    quantity_sum_1x10 = ('quantity','sum'),
    trades_count = ('product_name','count') )
category_gr['value_sum_1x1000'] = category_gr['value_sum_1x1000'] / 10000
category_gr['quantity_sum_1x10'] = category_gr['quantity_sum_1x10'] / 10


# Formatowanie wizualne 


category_gr
# Out:
#              value_sum_1x1000  quantity_sum_1x10  trades_count
# category
# Electronics          101.9751              117.3           113
# Food                 135.8239              174.6           173
# Furniture             99.5001              120.3           119
# Office                64.2803               92.8            95

# %%
category_gr.plot.bar(stacked=True)
plt.title('Stacked bar plot of Categories',size=25)
# Out:
# Text(0.5, 1.0, 'Stacked bar plot of Categories')
